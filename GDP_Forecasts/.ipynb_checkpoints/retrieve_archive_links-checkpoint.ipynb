# %%
"https://webarchive.nationalarchives.gov.uk/20100407010846/http://www.hm-treasury.gov.uk/data_forecasts_index.htm"

# %%
import pandas as pd
from tabula import read_pdf
import requests, bs4, time
import pandas as pd
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as soup
from datetime import date
import pickle

def extract_links(soup):
    links=[]
    for div in page_soup.find_all(name='div', attrs={'id':'primaryContentFull'}):
        for el in div.find_all(name='a'):
            links.append(el['href'])
    return [l  for l in links if '.pdf' in l]

def extract_links_2(soup):
    links =[]
    for div in soup.find_all(name='h2', attrs={'class':'title'}):
        links.append(div.a['href'])
    return links

def get_links():
    links=[]
    url="https://webarchive.nationalarchives.gov.uk/20100407010846/http://www.hm-treasury.gov.uk/data_forecasts_index.htm"
    req=Request(url, headers={'User-Agent': 'Mozilla/5.0'})
    webpage=urlopen(req).read()
    page_soup = soup(webpage, "html.parser")
    a=extract_links(page_soup)
    for element in a:
        links.append(element)
    return links


def make_links_dict(links,sub_links):
    sub_links_names = []
    for i in links[1:]:
        sub_links_names.append('_'.join(i.split('-')[-2:]))
    links_dict = dict(zip(sub_links_names,sub_links))
    return links_dict

# %%
a = get_links()

# %%
import calendar 
years = list(range(1997,2011,1))
years
months = list(calendar.month_name)
months
# Out:
# ['',
#  'January',
#  'February',
#  'March',
#  'April',
#  'May',
#  'June',
#  'July',
#  'August',
#  'September',
#  'October',
#  'November',
#  'December']

# %%
import PyPDF4
from urllib.request import urlopen
from io import BytesIO
import calendar 
years = list(range(1997,2011,1))
months = list(calendar.month_name)[1:]

links_dict = {}

for l in get_links():
    u = "https://webarchive.nationalarchives.gov.uk" + l
    url = u
    remoteFile = urlopen(Request(url)).read()
    memoryFile = BytesIO(remoteFile)
    reader = PyPDF4.PdfFileReader(memoryFile)
    page = reader.getPage(0)
    text = page.extractText()

    for x in months:
        if x in text:
            month = x
    for y in years:
        if str(y) in text:
            year = str(y)

    k = month.lower()+"_"+year
    links_dict[k] = u

# %%
text
# Out:
# 'HM Treasury\nFORECASTS FOR THE UK ECONOMY\nA comparison of independent forecasts\n \nCompiled by\nNo. 125\nEconomic Prospects Team\n       \nSeptember  1997 \n'

# %%
first = 4
second = 7
r = read_pdf(u,pages=[first,second])
# Out:
# Got stderr: May 05, 2020 9:55:13 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'TimesNewRomanPS-BoldMT' for 'TimesNewRoman-Bold'
# May 05, 2020 9:55:13 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'TimesNewRomanPS-BoldMT' for 'TimesNewRoman-Bold'
# May 05, 2020 9:55:13 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'TimesNewRomanPS-BoldMT' for 'TimesNewRoman-Bold'
# May 05, 2020 9:55:13 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'TimesNewRomanPS-BoldMT' for 'TimesNewRoman-Bold'
# May 05, 2020 9:55:13 PM org.apache.pdfbox.pdmodel.font.PDTrueTypeFont <init>
# WARNING: Using fallback font 'TimesNewRomanPS-BoldMT' for 'TimesNewRoman-Bold'

# %%
r[1]
# Out:
#                              City forecasters  Unnamed: 0 Unnamed: 1  \
# 0                 Abn Amro Hoare Govett Sept*         NaN        2.4
# 1                         Barclays Bank Sept*         NaN        3.0
# 2                                   BZW Sept*         NaN        2.1
# 3                          Charterhouse Sept*         NaN        3.3
# 4                       Chase Manhattan Sept*         NaN        2.0
# 5                       Credit Lyonnais Sept*         NaN        2.4
# 6                    Daiwa Europe Ltd/DIR Aug         NaN        1.8
# 7                          D M Grenfell Sept*         NaN        3.0
# 8                  Dresdner Kleinwort B Sept*         NaN        1.7
# 9                 Economic Perspectives Sept*         NaN        1.9
# 10                        Goldman Sachs Sept*         NaN        2.2
# 11                               Hermes Sept*         NaN        2.3
# 12                 HSBC Econ & Strategy Sept*         NaN        2.5
# ...

# %%
# contents = {}
# for i,x in enumerate(text.split('\n')):
#     if x.find('GDP')>0:
#         contents[x] = text.split('\n')[i+1]
#     else:
#         pass
# contents_dict[u]=contents

# %%
text
# Out:
# 'HM Treasury\nFORECASTS FOR THE UK ECONOMY\nA comparison of independent forecasts\n \nCompiled by\nNo. 125\nEconomic Prospects Team\n       \nSeptember  1997 \n'

# %%
if __name__ == "__main__":
    links_dict = make_links_dict(get_links(),get_sub_links(get_links()))
    data_dict=dict()
    for k in links_dict:
        if k in ['july_2017','april_2017','march_2017','august_2016','april_2016','march_2016','february_2016','january_2016','march_2013']: 
            afirst = 6
            second = 9
        else:
            first = 5
            second = 8
            
        data_dict[k] = read_pdf(links_dict[k],pages=[first,second])


    with open('C:/Users/lundr/economics/GDP_Forecasts/raw_data/all_data.pkl','wb') as f:
        pickle.dump(data_dict,f)
